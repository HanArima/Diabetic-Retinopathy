# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in c:\users\garima\anaconda3\lib\site-packages (1.0.7)
# Requirement already satisfied: huggingface_hub in c:\users\garima\anaconda3\lib\site-packages (from timm) (0.22.2)
# Requirement already satisfied: safetensors in c:\users\garima\anaconda3\lib\site-packages (from timm) (0.4.3)
# Requirement already satisfied: pyyaml in c:\users\garima\anaconda3\lib\site-packages (from timm) (6.0)
# Requirement already satisfied: torch in c:\users\garima\anaconda3\lib\site-packages (from timm) (2.3.1)
# Requirement already satisfied: torchvision in c:\users\garima\anaconda3\lib\site-packages (from timm) (0.18.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\garima\anaconda3\lib\site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: requests in c:\users\garima\anaconda3\lib\site-packages (from huggingface_hub->timm) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\garima\anaconda3\lib\site-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\garima\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\garima\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: filelock in c:\users\garima\anaconda3\lib\site-packages (from huggingface_hub->timm) (3.15.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\garima\anaconda3\lib\site-packages (from packaging>=20.9->huggingface_hub->timm) (3.0.4)
# Requirement already satisfied: colorama in c:\users\garima\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\garima\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garima\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\garima\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\garima\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2021.10.8)
# Requirement already satisfied: networkx in c:\users\garima\anaconda3\lib\site-packages (from torch->timm) (2.7.1)
# Requirement already satisfied: sympy in c:\users\garima\anaconda3\lib\site-packages (from torch->timm) (1.10.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\garima\anaconda3\lib\site-packages (from torch->timm) (2021.4.0)
# Requirement already satisfied: jinja2 in c:\users\garima\anaconda3\lib\site-packages (from torch->timm) (2.11.3)
# Requirement already satisfied: tbb==2021.* in c:\users\garima\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->timm) (2021.13.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\garima\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->timm) (2021.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\garima\anaconda3\lib\site-packages (from jinja2->torch->timm) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\garima\anaconda3\lib\site-packages (from sympy->torch->timm) (1.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\garima\anaconda3\lib\site-packages (from torchvision->timm) (10.2.0)
# Requirement already satisfied: numpy in c:\users\garima\anaconda3\lib\site-packages (from torchvision->timm) (1.26.4)
# Error processing line 1 of C:\Users\GARIMA\anaconda3\lib\site-packages\zope.interface-5.4.0-py3.9-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\GARIMA\anaconda3\Lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored

# %%
# !pip show timm
# Out:
# Name: timm
# Version: 1.0.7
# Summary: PyTorch Image Models
# Home-page: https://github.com/huggingface/pytorch-image-models
# Author:
# Author-email: Ross Wightman <ross@huggingface.co>
# License: Apache-2.0
# Location: c:\users\garima\anaconda3\lib\site-packages
# Requires: huggingface_hub, safetensors, torch, pyyaml, torchvision
# Required-by:
# Error processing line 1 of C:\Users\GARIMA\anaconda3\lib\site-packages\zope.interface-5.4.0-py3.9-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\GARIMA\anaconda3\Lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored

# %%
import timm
model = timm.create_model('inception_v4', pretrained=True)
model.eval()
# Out:
# model.safetensors:   0%|          | 0.00/171M [00:00<?, ?B/s]
# C:\Users\GARIMA\anaconda3\lib\site-packages\huggingface_hub\file_download.py:148: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\GARIMA\.cache\huggingface\hub\models--timm--inception_v4.tf_in1k. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# InceptionV4(
#   (features): Sequential(
#     (0): ConvNormAct(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNormAct2d(
#         32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#         (drop): Identity()
#         (act): ReLU(inplace=True)
#       )
#     )
#     (1): ConvNormAct(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#       (bn): BatchNormAct2d(
#         32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#         (drop): Identity()
#         (act): ReLU(inplace=True)
#       )
#     )
#     (2): ConvNormAct(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNormAct2d(
#         64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#         (drop): Identity()
#         (act): ReLU(inplace=True)
#       )
#     )
#     (3): Mixed3a(
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (conv): ConvNormAct(
#         (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (4): Mixed4a(
#       (branch0): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(160, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(160, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(64, 64, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Mixed5a(
#       (conv): ConvNormAct(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): InceptionA(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (7): InceptionA(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (8): InceptionA(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (9): InceptionA(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (10): ReductionA(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (11): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (12): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (13): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (14): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (15): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (16): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (17): InceptionB(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1024, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(192, 224, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(224, 224, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (4): ConvNormAct(
#           (conv): Conv2d(224, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (18): ReductionB(
#       (branch0): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch1): Sequential(
#         (0): ConvNormAct(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (1): ConvNormAct(
#           (conv): Conv2d(256, 256, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (2): ConvNormAct(
#           (conv): Conv2d(256, 320, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNormAct2d(
#             320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#         (3): ConvNormAct(
#           (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (bn): BatchNormAct2d(
#             320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (19): InceptionC(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_0): ConvNormAct(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_1a): ConvNormAct(
#         (conv): Conv2d(384, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_1b): ConvNormAct(
#         (conv): Conv2d(384, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_0): ConvNormAct(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_1): ConvNormAct(
#         (conv): Conv2d(384, 448, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_2): ConvNormAct(
#         (conv): Conv2d(448, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_3a): ConvNormAct(
#         (conv): Conv2d(512, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_3b): ConvNormAct(
#         (conv): Conv2d(512, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (20): InceptionC(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_0): ConvNormAct(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_1a): ConvNormAct(
#         (conv): Conv2d(384, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_1b): ConvNormAct(
#         (conv): Conv2d(384, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_0): ConvNormAct(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_1): ConvNormAct(
#         (conv): Conv2d(384, 448, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_2): ConvNormAct(
#         (conv): Conv2d(448, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_3a): ConvNormAct(
#         (conv): Conv2d(512, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_3b): ConvNormAct(
#         (conv): Conv2d(512, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (21): InceptionC(
#       (branch0): ConvNormAct(
#         (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_0): ConvNormAct(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_1a): ConvNormAct(
#         (conv): Conv2d(384, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch1_1b): ConvNormAct(
#         (conv): Conv2d(384, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_0): ConvNormAct(
#         (conv): Conv2d(1536, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_1): ConvNormAct(
#         (conv): Conv2d(384, 448, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_2): ConvNormAct(
#         (conv): Conv2d(448, 512, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_3a): ConvNormAct(
#         (conv): Conv2d(512, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch2_3b): ConvNormAct(
#         (conv): Conv2d(512, 256, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNormAct2d(
#           256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): ReLU(inplace=True)
#         )
#       )
#       (branch3): Sequential(
#         (0): AvgPool2d(kernel_size=3, stride=1, padding=1)
#         (1): ConvNormAct(
#           (conv): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (last_linear): Linear(in_features=1536, out_features=1000, bias=True)
# )

# %%
import torch
from PIL import Image
from torchvision import transforms

# %%
transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
image_path = 'C:/Users/GARIMA/OneDrive - UPES/Desktop/College Stuff/IBM Phemsoft/preprocess/20051020_43808_0100_PP.png'
image = Image.open(image_path)
input_tensor = transform(image).unsqueeze(0)

# %%
with torch.no_grad():
    output = model(input_tensor)
    _, predicted_class = output.max(1)

# %%
print(f"Predicted class index: {predicted_class.item()}")
# Out:
# Predicted class index: 619
